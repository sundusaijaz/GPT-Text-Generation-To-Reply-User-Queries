# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('/content/drive/MyDrive/James_Data/data.csv')

# %%
df.columns
# Out:
# Index(['subject', 'from', 'to', 'date', 'message', 'att'], dtype='object')

# %%
df.drop('att',axis=1,inplace=True)

# %%
df.head()
# Out:
#                                              subject  \
# 0  Bill for Feb 10, =?UTF-8?B?MjAyM+KAk0ZlYg==?= ...
# 1         Congrats on reaching 2K clicks in 28 days!
# 2  [Thunderstick Studios] Order #3934 placed by D...
# 3  [Thunderstick Studios] Order #3941 placed by J...
# 4                Shopify Experts are replying to you
#
#                                                 from  \
# 0              Shopify Billing <billing@shopify.com>
# 1  Google Search Console Team <sc-noreply@google....
# 2   Thunderstick Studios <sales@thunderjoystick.com>
# 3   Thunderstick Studios <sales@thunderjoystick.com>
# 4              Shopify Experts <experts@shopify.com>
#
#                           to                       date  \
# 0  sales@thunderjoystick.com  2023-02-10T09:42:01+00:00
# 1  sales@thunderjoystick.com  2023-02-09T05:54:17-08:00
# 2  sales@thunderjoystick.com  2023-02-09T18:32:59+00:00
# 3  sales@thunderjoystick.com  2023-02-10T01:55:22+00:00
# 4  sales@thunderjoystick.com  2023-02-09T12:00:08+00:00
#
#                                              message
# 0  You've been charged for your bill.\r\n\r\nYou'...
# 1  DQoNCg0KDQpTdWJqZWN0OiBDb25ncmF0cyBvbiByZWFjaG...
# 2  Daniel James placed order #3934 on Feb 09\r\na...
# 3  John Iacobucci placed order #3941 on Feb 10\r\...
# 4  You have 1 unread message\r\n\r\nMS Web Design...

# %%
df['to']
# Out:
# 0        sales@thunderjoystick.com
# 1        sales@thunderjoystick.com
# 2        sales@thunderjoystick.com
# 3        sales@thunderjoystick.com
# 4        sales@thunderjoystick.com
#                    ...
# 17982    sales@thunderjoystick.com
# 17983       jasonb1974@charter.net
# 17984    sales@thunderjoystick.com
# 17985    sales@thunderjoystick.com
# 17986    sales@thunderjoystick.com
# Name: to, Length: 17987, dtype: object

# %%
df['from']
# Out:
# 0                    Shopify Billing <billing@shopify.com>
# 1        Google Search Console Team <sc-noreply@google....
# 2         Thunderstick Studios <sales@thunderjoystick.com>
# 3         Thunderstick Studios <sales@thunderjoystick.com>
# 4                    Shopify Experts <experts@shopify.com>
#                                ...
# 17982     Thunderstick Studios <sales@thunderjoystick.com>
# 17983      Thunderstick Studio <sales@thunderjoystick.com>
# 17984    "Thunderstick Studios (Shopify)" <mailer@shopi...
# 17985     Thunderstick Studios <sales@thunderjoystick.com>
# 17986    "Thunderstick Studios (Shopify)" <mailer@shopi...
# Name: from, Length: 17987, dtype: object

# %%
class CleanData():

  def clean_text(self,text):
    text = str(text)
    # remove non-ASCII characters
    text = text.encode("ascii", "ignore").decode()

    # remove URLs
    text = re.sub(r"http\S+", " ", text)

    # remove HTML tags
    text = re.sub(r"<.*?>", " ", text)

    # remove punctuation and special characters
    text = re.sub(r"[^a-zA-Z0-9\s]", " ", text)

    # convert all characters to lowercase
    text = text.lower()

    # remove extra whitespace
    text = re.sub(r"\s+", " ", text).strip()

    return text
  def GetEmails(self,mail):
    mail = str(mail)
    mail = mail.split()[-1]
 
    if mail.endswith('.com>') and '@' in mail:
      
      return mail[1:-1]
  def GetData(self,date):
    mail = str(mail)
    mail = mail.split()

  def correct_spelling_and_abbreviations(self,text):
    # Define a dictionary of common misspellings and their correct forms
    misspellings = {
        "w/o": "without",
        "w/": "with",
        "thru": "through",
        "abt": "about",
        "nxt": "next",
        "2moro": "tomorrow",
        "2day": "today",
        "tnite": "tonight",
        "u": "you",
        "ur": "your"
    }
    
    # Replace misspellings and abbreviations with their correct forms
    for misspelling, correct in misspellings.items():
        text = re.sub(r"\b" + misspelling + r"\b", correct, text)

    return text




obj = CleanData()

# %%
df['subject'] = df['subject'].map(obj.clean_text)
df['from[MAIL]']  = df['from'].map(obj.GetEmails)
df['from[Name]'] = df['from'].map(lambda x: str(x).split()[0])
df['date']=df['date'].map(lambda x: str(x).split(':')[0][:10])

# %%
new_df = pd.DataFrame({
    'date':df['date'],
    'Subject':df['subject'],
    'To':df['to'],
    "From[Title]":df['from[Name]'],
    'From[Mail]':df['from[MAIL]'],
    'message':df['message'],
})

# %%
new_df
# Out:
#              date                                            Subject  \
# 0      2023-02-10  bill for feb 10 utf 8 b mjaym kak0zlyg 10 2024...
# 1      2023-02-09          congrats on reaching 2k clicks in 28 days
# 2      2023-02-09  thunderstick studios order 3934 placed by dani...
# 3      2023-02-10  thunderstick studios order 3941 placed by john...
# 4      2023-02-09                shopify experts are replying to you
# ...           ...                                                ...
# 17982  2023-01-17  thunderstick studios order 3513 placed by char...
# 17983  2023-01-08  re new customer message on january 7 2023 at 5...
# 17984  2023-01-07  new customer message on january 7 2023 at 5 25 am
# 17985  2022-12-03  thunderstick studios order 2944 placed by nola...
# 17986  2023-01-30  new customer message on january 30 2023 at 8 0...
#
#                               To    From[Title]                 From[Mail]  \
# 0      sales@thunderjoystick.com        Shopify        billing@shopify.com
# 1      sales@thunderjoystick.com         Google      sc-noreply@google.com
# 2      sales@thunderjoystick.com   Thunderstick  sales@thunderjoystick.com
# 3      sales@thunderjoystick.com   Thunderstick  sales@thunderjoystick.com
# 4      sales@thunderjoystick.com        Shopify        experts@shopify.com
# ...                          ...            ...                        ...
# 17982  sales@thunderjoystick.com   Thunderstick  sales@thunderjoystick.com
# 17983     jasonb1974@charter.net   Thunderstick  sales@thunderjoystick.com
# 17984  sales@thunderjoystick.com  "Thunderstick         mailer@shopify.com
# 17985  sales@thunderjoystick.com   Thunderstick  sales@thunderjoystick.com
# 17986  sales@thunderjoystick.com  "Thunderstick         mailer@shopify.com
#
#                                                  message
# 0      You've been charged for your bill.\r\n\r\nYou'...
# 1      DQoNCg0KDQpTdWJqZWN0OiBDb25ncmF0cyBvbiByZWFjaG...
# 2      Daniel James placed order #3934 on Feb 09\r\na...
# 3      John Iacobucci placed order #3941 on Feb 10\r\...
# 4      You have 1 unread message\r\n\r\nMS Web Design...
# ...                                                  ...
# 17982  Charles E  Kieser placed order #3513 on Jan\r\...
# 17983  Hi John,\r\n\r\nAppreciate your feedback. Unfo...
# 17984  You received a new message from your online st...
# 17985  Nolan Schuller placed order #2944 on Dec 03\r\...
# 17986  You received a new message from your online st...
#
# [17987 rows x 6 columns]

# %%
new_df.to_csv('/content/drive/MyDrive/James_Data/Allahwastaykadata.csv')

# %%
new_df['Subject'][20:80]
# Out:
# 20    re new customer message on february 9 2023 at ...
# 21    new customer message on february 9 2023 at 7 2...
# 22    thunderstick studios order 3869 placed by chri...
# 23    thunderstick studios order 3922 placed by timo...
# 24    thunderstick studios order 3892 placed by patr...
# 25                        re upgrade my 12 game machine
# 26                        re upgrade my 12 game machine
# 27                        re upgrade my 12 game machine
# 28                        re upgrade my 12 game machine
# 29                           upgrade my 12 game machine
# 30    thunderstick studios order 3806 placed by gonz...
# 31    invitation google thunderstick studio google a...
# 32    email 2 4 your complete guide to routers and f...
# 33    thunderstick studios order 3846 placed by mich...
# 34    thunderstick studios order 3942 placed by jose...
# 35    thunderstick studios order 3834 placed by crai...
# 36    re new customer message on january 29 2023 at ...
# 37    new customer message on january 29 2023 at 12 ...
# 38    thunderstick studios order 3825 placed by doug...
# 39    thunderstick studios order 3829 placed by mich...
# 40    thunderstick studios order 3822 placed by mike...
# 41    thunderstick studios order 3824 placed by step...
# 42    reminder tell us about your google ads experience
# 43    thunderstick studios order 3798 placed by anth...
# 44        re imp website speed matter for thunder stick
# 45        re imp website speed matter for thunder stick
# 46        re imp website speed matter for thunder stick
# 47        re imp website speed matter for thunder stick
# 48        re imp website speed matter for thunder stick
# 49        re imp website speed matter for thunder stick
# 50        re imp website speed matter for thunder stick
# 51           imp website speed matter for thunder stick
# 52                                    business proposal
# 53    re new customer message on january 27 2023 at ...
# 54    new customer message on january 27 2023 at 11 ...
# 55    new customer message on january 27 2023 at 11 ...
# 56    thunderstick studios order 3677 placed by davi...
# 57    re tos grs switchable 4 to 8 way restrictor fo...
# 58    re tos grs switchable 4 to 8 way restrictor fo...
# 59    re tos grs switchable 4 to 8 way restrictor fo...
# 60    re tos grs switchable 4 to 8 way restrictor fo...
# 61    tos grs switchable 4 to 8 way restrictor for s...
# 62    thunderstick studios order 3921 placed by russ...
# 63    thunderstick studios order 3765 placed by nola...
# 64    thunderstick studios order 3651 placed by nich...
# 65    thunderstick studios order 3777 placed by stev...
# 66                      thank you for joining us at ces
# 67    thunderstick studios order 3794 placed by mr r...
# 68    thunderstick studios order 3571 placed by davi...
# 69    thunderstick studios order 3476 placed by jere...
# 70    thunderstick studios order 3657 placed by chri...
# 71    thunderstick studios order 3540 placed by fran...
# 72    thunderstick studios order 3788 placed by vega...
# 73                 delivery status notification failure
# 74                   delivery status notification delay
# 75                 delivery status notification failure
# 76                   delivery status notification delay
# 77                              re order 3524 confirmed
# 78                              re order 3524 confirmed
# 79                              re order 3524 confirmed
# Name: Subject, dtype: object

# %%
print(new_df['message'][17977])
# Out:
# Hi Tony,
#
# The shipping agent told us they could not deliver to your address.
#
# Can you contact your local Aramex(link below) and provide them with your
# tracking number: BN5113982293? It looks like they are waiting
# for instructions from you.
# https://www.aramex.com.au/contact-us/aramex-depot/
#
#
# On Thu, Dec 8, 2022 at 10:37 AM Thunderstick Studio <
# sales@thunderjoystick.com> wrote:
#
# > I appreciate your understanding. We have Australian customers who have
# > already received their packages, so why is it taking so long. Hoping the
# > package is not lost. If so, I will resent the box to you
# >
# > On Thu, Dec 8, 2022 at 10:32 AM Tony Cruise <tcruise@cruiseresearch.com.a=
# u>
# > wrote:
# >
# >> Thanks, at least I can see the tracking now, all good understand
# >> shipments take some time nowadays.
# >>
# >>
# >>
# >> Regards
# >>
# >> Tony
# >>
# >>
# >>
# >> *From:* Thunderstick Studio <sales@thunderjoystick.com>
# >> *Sent:* Thursday, 8 December 2022 1:30 PM
# >> *To:* Tony Cruise <tcruise@cruiseresearch.com.au>
# >> *Subject:* Re: Order #1583Are
# >>
# >>
# >>
# >> Hi Tony,
# >>
# >>
# >>
# >> The package was shipped ages ago. Please use this link to track this
# >> order: https://t.17track.net/en?v=3D2#nums=3DBN5113982293
# >> <https://na01.safelinks.protection.outlook.com/?url=3Dhttps%3A%2F%2Ft.17=
# track.net%2Fen%3Fv%3D2%23nums%3DBN5113982293&data=3D05%7C01%7C%7C8a9fda060d=
# f5486dd47508dad8c4160f%7C84df9e7fe9f640afb435aaaaaaaaaaaa%7C1%7C0%7C6380606=
# 33937617932%7CUnknown%7CTWFpbGZsb3d8eyJWIjoiMC4wLjAwMDAiLCJQIjoiV2luMzIiLCJ=
# BTiI6Ik1haWwiLCJXVCI6Mn0%3D%7C3000%7C%7C%7C&sdata=3DNqd4LtxwjCGI%2FdzQ1qAOA=
# TAc1bu3c%2FzZP2YA%2FmBDiKs%3D&reserved=3D0>
# >>
# >>
# >>
# >> It seen to be stocked in Sydney, I am checking now. will keep you posted
# >>
# >>
# >>
# >> On Thu, Dec 8, 2022 at 10:19 AM Tony Cruise <
# >> tcruise@cruiseresearch.com.au> wrote:
# >>
# >>
# >>
# >>
# >>
# >> Are there any updates on when this order will ship?  The tracking number
# >> does not return any results.
# >>
# >>
# >>
# >> Regards
# >>
# >> Tony
# >>
# >>
# >>
# >>
# >> --
# >>
# >> *Thunderstick Studio*
# >>
# >
# >
# > --
# >
# > *Thunderstick Studio*
# >
#
#
# --=20
#
# *Thunderstick Studio*

# %%
replies = new_df[new_df['Subject'].str.startswith("re ")]

# %%
replies
# Out:
#              date                                            Subject  \
# 7      2023-02-09                             re asteroids partycade
# 18     2023-02-10  re new customer message on february 9 2023 at ...
# 19     2023-02-09  re new customer message on february 9 2023 at ...
# 20     2023-02-09  re new customer message on february 9 2023 at ...
# 25     2023-02-10                      re upgrade my 12 game machine
# ...           ...                                                ...
# 17977  2022-12-12                                   re order 1583are
# 17978  2022-12-08                                   re order 1583are
# 17979  2022-12-08                                   re order 1583are
# 17980  2022-12-08                                   re order 1583are
# 17983  2023-01-08  re new customer message on january 7 2023 at 5...
#
#                                                     To   From[Title]  \
# 7        "Emerson, Lanson" <Lanson.Emerson@garmin.com>  Thunderstick
# 18                "Cavin Hall, Jr" <cbhjr1973@att.net>  Thunderstick
# 19     Thunderstick Studio <sales@thunderjoystick.com>        "Cavin
# 20                                   cbhjr1973@att.net  Thunderstick
# 25                 Vetteguy <vetteguy1969@bresnan.net>  Thunderstick
# ...                                                ...           ...
# 17977      Tony Cruise <tcruise@cruiseresearch.com.au>  Thunderstick
# 17978      Tony Cruise <tcruise@cruiseresearch.com.au>  Thunderstick
# 17979  Thunderstick Studio <sales@thunderjoystick.com>          Tony
# 17980      Tony Cruise <tcruise@cruiseresearch.com.au>  Thunderstick
# 17983                           jasonb1974@charter.net  Thunderstick
#
#                       From[Mail]  \
# 7      sales@thunderjoystick.com
# 18     sales@thunderjoystick.com
# 19                          None
# 20     sales@thunderjoystick.com
# 25     sales@thunderjoystick.com
# ...                          ...
# 17977  sales@thunderjoystick.com
# 17978  sales@thunderjoystick.com
# 17979                       None
# 17980  sales@thunderjoystick.com
# 17983  sales@thunderjoystick.com
#
#                                                  message
# 7      Hi Lanson,\r\n\r\nI am sorry, but we don't hav...
# 18     Hi Cavin,\r\n\r\nI have attached the user manu...
# 19      Thank you so much for the info. Will the joys...
# 20     Hey Cavin,\r\n\r\nHope you're doing well! I ju...
# 25     Thanks for sharing the picture of your cabinet...
# ...                                                  ...
# 17977  Hi Tony,\r\n\r\nThe shipping agent told us the...
# 17978  I appreciate your understanding. We have Austr...
# 17979  Thanks, at least I can see the tracking now, a...
# 17980  Hi Tony,\r\n\r\nThe package was shipped ages a...
# 17983  Hi John,\r\n\r\nAppreciate your feedback. Unfo...
#
# [8183 rows x 6 columns]

# %%
replies.to_csv('/content/drive/MyDrive/James_Data/Sadqaalelodata.csv')
